# %% [markdown]
# <a href="https://colab.research.google.com/github/thanga-v2/using_Fast-API/blob/main/simple_gpt2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install --upgrade huggingface_hub
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.5/417.5 kB 23.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface-hub 0.24.6
#     Uninstalling huggingface-hub-0.24.6:
#       Successfully uninstalled huggingface-hub-0.24.6
# ...

# %%
from google.colab import userdata

# %%
from huggingface_hub import InferenceClient


client = InferenceClient(model="gpt2", token=userdata.get('commonwrite'))

prompt = "what does tesla do?"
response = client.text_generation(prompt, max_new_tokens=200)
print(response)
# Out:
# The answer is that it's a very simple thing. It's a simple thing. It's a simple thing. It's a simple thing. It's a simple thing. It's a simple thing. It's a simple thing. It's a simple thing. It's a simple thing. It's a simple thing. It's a simple thing. It's a simple thing. It's a simple thing. It's a simple thing. It's a simple thing. It's a simple thing. It's a simple thing. It's a simple thing. It's a simple thing. It's a simple thing. It's a simple thing. It's a simple thing. It's a simple thing. It's a simple thing. It's a simple thing. It's a simple thing. It's a simple thing. It's a simple thing. It's a simple thing. It's a simple thing. It's a simple thing. It's a simple thing. It

# %%
# question answering

qaclient = InferenceClient(model="deepset/bert-large-uncased-whole-word-masking-squad2", token=userdata.get('commonwrite'))

experiment = qaclient.question_answering(question="who is virat kohli?",context="On 18 December 2006, Kohli experienced the loss of his father due to a cerebral attack.[13][16] During his childhood, his father played a crucial role in supporting his cricket training. Kohli has credited his father as the one who drove him to practice every day. He has expressed his feelings of missing his father's presence at times.[10][17] According to his mother, Kohli's demeanour shifted noticeably after his father's death. He took cricket with newfound seriousness, prioritizing playing time and dedicating himself fully to the sport.[13] Kohli's family resided in Meera Bagh, Paschim Vihar until the year 2015, after which they relocated to Gurgaon.[18]")

print(experiment)
# Out:
# QuestionAnsweringOutputElement(answer='cricket', end=176, score=0.03266143053770065, start=169)

# %%
# text to image

imgclient = InferenceClient(model="black-forest-labs/FLUX.1-dev", token=userdata.get('commonwrite'))

prompt = "One fine weather day in Coimbatore, evening time, birds are flying back to her home, sunset, mountain view"
result = imgclient.text_to_image(prompt)

result
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x1024>
